# %% [markdown]
# ### Pair Programming Pandas III ###

# %% [markdown]
# **1** Cargar el dataset
#
# 💡 Pista Si hacemos la carga del dataset sin el parámetro encoding nos puede dar error (puede que no os de error, si es así menos problemas!). Aquí tenéis una lista de los encodings disponibles en pandas. Buscad por los encoding de tipo ISO.

# %%
import pandas as pd

# %%
df = pd.read_csv("attacks_pandasIII.csv")

# %%
df.head()
# Out:
#    Unnamed: 0 Case Number    Year        Type    Country             Area  \
# 0           0  2018.06.25  2018.0     Boating        USA       California
# 1           1  2018.06.18  2018.0  Unprovoked        USA          Georgia
# 2           2  2018.06.09  2018.0     Invalid        USA           Hawaii
# 3           3  2018.06.08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4           4  2018.06.04  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %% [markdown]
# **2**. Haced una exploración básica del DataFrame:
#
# **2.1** ¿Cuántas filas y columnas tiene el DataFrame?

# %%
df.shape
# Out:
# (6114, 22)

# %% [markdown]
# **2.2** Mostrad las primeras cinco filas y las últimas cinco filas del DataFrame.

# %%
# cinco primeras
df.head(5)
# Out:
#    Unnamed: 0 Case Number    Year        Type    Country             Area  \
# 0           0  2018.06.25  2018.0     Boating        USA       California
# 1           1  2018.06.18  2018.0  Unprovoked        USA          Georgia
# 2           2  2018.06.09  2018.0     Invalid        USA           Hawaii
# 3           3  2018.06.08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4           4  2018.06.04  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
# cinco últimas
df.tail(5)
# Out:
#       Unnamed: 0   Case Number    Year          Type    Country  \
# 6109        6127  1804.02.26.R  1804.0          Boat  AUSTRALIA
# 6110        6128    1803.05.17  1803.0  Sea Disaster        USA
# 6111        6129    1803.03.00  1803.0    Unprovoked  AUSTRALIA
# 6112        6130  1802.04.13.R  1802.0    Unprovoked      INDIA
# 6113        6131  1801.12.18.R  1801.0      Provoked        NaN
#
#                    Area                          Location  \
# 6109    New South Wales    Georges Head, off Port Jackson
# 6110     South Carolina                    Off Charleston
# 6111  Western Australia  Hamelin Harbour, at Faure Island
# 6112                NaN                               NaN
# 6113                NaN                               NaN
#
#                              Activity                             Name Sex   \
# 6109                              NaN                             boat  NaN
# ...

# %% [markdown]
# **2.3** Mostrad 2 filas al azar del DataFrame.

# %%
df.sample(2)
# Out:
#       Unnamed: 0 Case Number    Year      Type      Country          Area  \
# 3514        3524  1967.06.13  1967.0  Provoked          USA       Florida
# 4029        4041  1959.12.03  1959.0      Boat  NEW ZEALAND  North Island
#
#                      Location             Activity  \
# 3514  Key West, Monroe County         Spearfishing
# 4029              Moko Hinau   Fishing for snapper
#
#                               Name Sex   ...                 Species   \
# 3514        Andres Puma (or Pruna)    M  ...        Nurse shark, 1 m
# 4029  dinghy, occupant: Don Ashton    M  ...  Mako shark, 4.3 m [14']
#
#                          Investigator or Source                         pdf  \
# 3514  H.D. Baldridge, p.192; M. McDiarmid, p.70        1967.06.13-Pruna.pdf
# 4029                          Captain C. Morris  1959.12.03-boat-Ashton.pdf
#
#                                            href formula  \
# 3514  http://sharkattackfile.net/spreadsheets/pdf_di...
# ...

# %% [markdown]
# **2.4**¿Cuál es el nombre de las columnas del DataFrame?

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Case Number', 'Year', 'Type', 'Country', 'Area',
#        'Location', 'Activity', 'Name', 'Sex ', 'Age', 'Time', 'Species ',
#        'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %% [markdown]
# **2.5** ¿Cuáles son los principales estádisticos del DataFrame? Mostrad por separado las variables categóricas y las variables numéricas.

# %%
# variables categóricas
df.describe(include="object")
# Out:
#        Case Number        Type Country     Area  \
# count         6113        6110    6074     5706
# unique        6113           8     201      791
# top     2018.06.25  Unprovoked     USA  Florida
# freq             1        4438    2200     1025
#
#                                 Location Activity  Name  Sex    Age  \
# count                               5626     5603  5914  5564  3448
# unique                              4020     1484  5118     6   156
# top     New Smyrna Beach, Volusia County  Surfing  male     M    17
# freq                                 162      966   511  4939   154
#
#              Time     Species  Investigator or Source                     pdf  \
# count        2934         3409                   6098                    6114
# unique        366         1529                   4837                    6105
# top     Afternoon  White shark         C. Moore, GSAF  1898.00.00.R-Syria.pdf
# ...

# %%
# variables numéricas
df.describe()
# Out:
#         Unnamed: 0         Year  original order
# count  6114.000000  6114.000000     6114.000000
# mean   3065.554629  1968.831207     3237.445044
# std    1769.652139    43.745920     1769.652633
# min       0.000000  1801.000000      172.000000
# 25%    1534.250000  1946.000000     1706.250000
# 50%    3066.500000  1980.000000     3236.500000
# 75%    4596.750000  2005.000000     4768.750000
# max    6131.000000  2018.000000     6303.000000

# %% [markdown]
# **2.6** ¿Cuál es el porcentaje de valores nulos en cada columna?

# %%
(df.isnull().sum() / (len(df))* 100)
# Out:
# Unnamed: 0                 0.000000
# Case Number                0.016356
# Year                       0.000000
# Type                       0.065424
# Country                    0.654236
# Area                       6.673209
# Location                   7.981681
# Activity                   8.357867
# Name                       3.271181
# Sex                        8.995747
# Age                       43.604841
# Time                      52.011776
# Species                   44.242722
# Investigator or Source     0.261694
# pdf                        0.000000
# href formula               0.016356
# href                       0.000000
# Case Number.1              0.000000
# Case Number.2              0.000000
# original order             0.000000
# Unnamed: 22               99.983644
# Unnamed: 23               99.967288
# dtype: float64

# %% [markdown]
# **2.7** Sacad los valores únicos y su frecuencia de las variables numéricas. Almacenad los resultados en un diccionario. Uno para cada variable.

# %%
# Identificamos las variables numéricas
seleccion = df.select_dtypes(include = ["int16", "int32", "int64", "float16", "float32", "float64"])
seleccion.head()
# Out:
#    unnamed:_0    year  original_order
# 0           0  2018.0          6303.0
# 1           1  2018.0          6302.0
# 2           2  2018.0          6301.0
# 3           3  2018.0          6300.0
# 4           4  2018.0          6299.0

# %%
# Creamos tres diccionarios, ya que existen tres variables numéricas
dicc2= {}
dicc3= {}
dicc4= {}

# %%
# Con un for vamos añadiendo a los diccionarios las variables y sus valores.
for col in df.columns:
    if col == "unnamed:_0":
        dicc2.setdefault(col, df[col].value_counts())
    elif col == "year":
        dicc3.setdefault(col, df[col].value_counts())
    elif col == "original_order":
        dicc4.setdefault(col, df[col].value_counts())

# %%
dicc2
# Out:
# {'unnamed:_0': 0       1
#  4084    1
#  4093    1
#  4092    1
#  4091    1
#         ..
#  2043    1
#  2042    1
#  2041    1
#  2040    1
#  6131    1
#  Name: unnamed:_0, Length: 6114, dtype: int64}

# %%
dicc3
# Out:
# {'year': 2015.0    143
#  2017.0    136
#  2016.0    130
#  2011.0    128
#  2014.0    126
#           ...
#  1819.0      1
#  1822.0      1
#  1823.0      1
#  1834.0      1
#  1801.0      1
#  Name: year, Length: 207, dtype: int64}

# %%
dicc4
# Out:
# {'original_order': 569.0     2
#  6303.0    1
#  2208.0    1
#  2210.0    1
#  2211.0    1
#           ..
#  4260.0    1
#  4261.0    1
#  4262.0    1
#  4263.0    1
#  172.0     1
#  Name: original_order, Length: 6113, dtype: int64}

# %% [markdown]
# **2.8** Cambiad el nombre de las columnas para que todas estén en minúsculas y reemplazad los espacios por _.

# %%
df2 = df.copy()
df2.head()
# Out:
#    Unnamed: 0 Case Number    Year        Type    Country             Area  \
# 0           0  2018.06.25  2018.0     Boating        USA       California
# 1           1  2018.06.18  2018.0  Unprovoked        USA          Georgia
# 2           2  2018.06.09  2018.0     Invalid        USA           Hawaii
# 3           3  2018.06.08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4           4  2018.06.04  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
columnas_min = {col:col.lower().replace(" ","_") for col in df.columns}

# %%
df.rename(columns = columnas_min, inplace=True)

# %%
df.head()
# Out:
#    unnamed:_0 case_number    year        type    country             area  \
# 0           0  2018.06.25  2018.0     Boating        USA       California
# 1           1  2018.06.18  2018.0  Unprovoked        USA          Georgia
# 2           2  2018.06.09  2018.0     Invalid        USA           Hawaii
# 3           3  2018.06.08  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4           4  2018.06.04  2018.0    Provoked     MEXICO           Colima
#
#                          location     activity             name sex_  ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %% [markdown]
# **2.9** Eliminad las columnas de Unnamed: 22 y Unnamed: 23, Case Number.1, Case Number.2, original order, Investigator or Source, pdf, href formula.

# %%
df2.columns
# Out:
# Index(['Unnamed: 0', 'Case Number', 'Year', 'Type', 'Country', 'Area',
#        'Location', 'Activity', 'Name', 'Sex ', 'Age', 'Time', 'Species ',
#        'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
df_eliminar = df2.drop(["Unnamed: 22","Unnamed: 23", 
                        "Case Number.1", "Case Number.2", 
                        "original order", "Investigator or Source", 
                        "pdf", "href formula"], axis =1)

# %%
df_eliminar
# Out:
#       Unnamed: 0   Case Number    Year          Type    Country  \
# 0              0    2018.06.25  2018.0       Boating        USA
# 1              1    2018.06.18  2018.0    Unprovoked        USA
# 2              2    2018.06.09  2018.0       Invalid        USA
# 3              3    2018.06.08  2018.0    Unprovoked  AUSTRALIA
# 4              4    2018.06.04  2018.0      Provoked     MEXICO
# ...          ...           ...     ...           ...        ...
# 6109        6127  1804.02.26.R  1804.0          Boat  AUSTRALIA
# 6110        6128    1803.05.17  1803.0  Sea Disaster        USA
# 6111        6129    1803.03.00  1803.0    Unprovoked  AUSTRALIA
# 6112        6130  1802.04.13.R  1802.0    Unprovoked      INDIA
# 6113        6131  1801.12.18.R  1801.0      Provoked        NaN
#
#                    Area                          Location  \
# 0            California       Oceanside, San Diego County
# 1               Georgia    St. Simon Island, Glynn County
# ...

# %% [markdown]
# **2.10** Establece la columna Case Number como índice del DataFrame.

# %%
df_eliminar.set_index(["Case Number"], inplace=True)

# %%
df_eliminar
# Out:
#               Unnamed: 0    Year          Type    Country               Area  \
# Case Number
# 2018.06.25             0  2018.0       Boating        USA         California
# 2018.06.18             1  2018.0    Unprovoked        USA            Georgia
# 2018.06.09             2  2018.0       Invalid        USA             Hawaii
# 2018.06.08             3  2018.0    Unprovoked  AUSTRALIA    New South Wales
# 2018.06.04             4  2018.0      Provoked     MEXICO             Colima
# ...                  ...     ...           ...        ...                ...
# 1804.02.26.R        6127  1804.0          Boat  AUSTRALIA    New South Wales
# 1803.05.17          6128  1803.0  Sea Disaster        USA     South Carolina
# 1803.03.00          6129  1803.0    Unprovoked  AUSTRALIA  Western Australia
# 1802.04.13.R        6130  1802.0    Unprovoked      INDIA                NaN
# 1801.12.18.R        6131  1801.0      Provoked        NaN                NaN
#
# ...

# %% [markdown]
# **3.** Guarda el csv que no tiene esas columnas para seguir usándolo mañana.

# %%
df_eliminar.to_csv("datos_sincolumnas.csv")
